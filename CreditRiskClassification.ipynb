# %%
#*******************************************************************************************
 #
 #  File Name:  CreditRiskClassification.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, CreditRiskClassification.ipynb, reads a csv file,
 #      LendingData.csv, in the Resources folder, and uses Python and supervised learning
 #      methods to use a dataset of historical lending activity from a peer-to-peer lending
 #      lending services company to build a model that can identify the creditworthiness
 #      of borrowers. 
 #
 #      I reinstalled the scikit-learn module using the following commands to allow the
 #      RandomOverSampler function to work:
 #
 #      pip3 uninstall scikit-learn
 #      pip3 install scikit-learn==1.2.2
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  11/25/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import CreditRiskClassificationFunctions as local_function

import PyConstants as constant
import PyFunctions as function
import PyLogConstants as log_constant
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import PySubRoutines as subroutine

import numpy as np
import pandas as pd

from pathlib import Path

from imblearn.over_sampling import RandomOverSampler

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'CreditRiskClassification.ipynb'

CONSTANT_LENDING_DATA_CSV_FILE_PATH \
    = './Resources/LendingData.csv'

log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)

log_subroutine \
    .BeginProgramExecution \
        ('CreditRiskClassification')

# %% [markdown]
# # <br> **Section 1: Split the Data into Training and Testing Sets**

# %% [markdown]
# ## **1.1: Read the CSV data from the `Resources` folder into a Pandas DataFrame**

# %% [markdown]
# ### **Read the CSV data from the `Resources` folder**

# %%
lendingDataFrame \
    = function. \
        ReturnCSVFileAsDataFrame \
            (CONSTANT_LENDING_DATA_CSV_FILE_PATH)


log_function \
    .DebugReturnObjectWriteObject \
        (lendingDataFrame)

# %% [markdown]
# ### **Display Lending DataFrame**

# %%
captionString \
    = 'Table 1.2.1: Lending Data Table'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (lendingDataFrame.head(12),
             captionString) \
        .format({'loan_size': '${:,.0f}',
                 'interest_rate': '{:.2f}%',
                 'borrower_income': '${:,.0f}',
                 'total_debt': '${:,.0f}'})

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_84eee caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_84eee_row0_col0, #T_84eee_row0_col1, #T_84eee_row0_col2, #T_84eee_row0_col3, #T_84eee_row0_col4, #T_84eee_row0_col5, #T_84eee_row0_col6, #T_84eee_row0_col7, #T_84eee_row1_col0, #T_84eee_row1_col1, #T_84eee_row1_col2, #T_84eee_row1_col3, #T_84eee_row1_col4, #T_84eee_row1_col5, #T_84eee_row1_col6, #T_84eee_row1_col7, #T_84eee_row2_col0, #T_84eee_row2_col1, #T_84eee_row2_col2, #T_84eee_row2_col3, #T_84eee_row2_col4, #T_84eee_row2_col5, #T_84eee_row2_col6, #T_84eee_row2_col7, #T_84eee_row3_col0, #T_84eee_row3_col1, #T_84eee_row3_col2, #T_84eee_row3_col3, #T_84eee_row3_col4, #T_84eee_row3_col5, #T_84eee_row3_col6, #T_84eee_row3_col7, #T_84eee_row4_col0, #T_84eee_row4_col1, #T_84eee_row4_col2, #T_84eee_row4_col3, #T_84eee_row4_col4, #T_84eee_row4_col5, #T_84eee_row4_col6, #T_84eee_row4_col7, #T_84eee_row5_col0, #T_84eee_row5_col1, #T_84eee_row5_col2, #T_84eee_row5_col3, #T_84eee_row5_col4, #T_84eee_row5_col5, #T_84eee_row5_col6, #T_84eee_row5_col7, #T_84eee_row6_col0, #T_84eee_row6_col1, #T_84eee_row6_col2, #T_84eee_row6_col3, #T_84eee_row6_col4, #T_84eee_row6_col5, #T_84eee_row6_col6, #T_84eee_row6_col7, #T_84eee_row7_col0, #T_84eee_row7_col1, #T_84eee_row7_col2, #T_84eee_row7_col3, #T_84eee_row7_col4, #T_84eee_row7_col5, #T_84eee_row7_col6, #T_84eee_row7_col7, #T_84eee_row8_col0, #T_84eee_row8_col1, #T_84eee_row8_col2, #T_84eee_row8_col3, #T_84eee_row8_col4, #T_84eee_row8_col5, #T_84eee_row8_col6, #T_84eee_row8_col7, #T_84eee_row9_col0, #T_84eee_row9_col1, #T_84eee_row9_col2, #T_84eee_row9_col3, #T_84eee_row9_col4, #T_84eee_row9_col5, #T_84eee_row9_col6, #T_84eee_row9_col7, #T_84eee_row10_col0, #T_84eee_row10_col1, #T_84eee_row10_col2, #T_84eee_row10_col3, #T_84eee_row10_col4, #T_84eee_row10_col5, #T_84eee_row10_col6, #T_84eee_row10_col7, #T_84eee_row11_col0, #T_84eee_row11_col1, #T_84eee_row11_col2, #T_84eee_row11_col3, #T_84eee_row11_col4, #T_84eee_row11_col5, #T_84eee_row11_col6, #T_84eee_row11_col7 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_84eee">
#   <caption>Table 1.2.1: Lending Data Table</caption>
#   <thead>
#     <tr>
#       <th id="T_84eee_level0_col0" class="col_heading level0 col0" >loan_size</th>
#       <th id="T_84eee_level0_col1" class="col_heading level0 col1" >interest_rate</th>
#       <th id="T_84eee_level0_col2" class="col_heading level0 col2" >borrower_income</th>
#       <th id="T_84eee_level0_col3" class="col_heading level0 col3" >debt_to_income</th>
#       <th id="T_84eee_level0_col4" class="col_heading level0 col4" >num_of_accounts</th>
#       <th id="T_84eee_level0_col5" class="col_heading level0 col5" >derogatory_marks</th>
#       <th id="T_84eee_level0_col6" class="col_heading level0 col6" >total_debt</th>
#       <th id="T_84eee_level0_col7" class="col_heading level0 col7" >loan_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84eee_row0_col0" class="data row0 col0" >$10,700</td>
#       <td id="T_84eee_row0_col1" class="data row0 col1" >7.67%</td>
#       <td id="T_84eee_row0_col2" class="data row0 col2" >$52,800</td>
#       <td id="T_84eee_row0_col3" class="data row0 col3" >0.431818</td>
#       <td id="T_84eee_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_84eee_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_84eee_row0_col6" class="data row0 col6" >$22,800</td>
#       <td id="T_84eee_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row1_col0" class="data row1 col0" >$8,400</td>
#       <td id="T_84eee_row1_col1" class="data row1 col1" >6.69%</td>
#       <td id="T_84eee_row1_col2" class="data row1 col2" >$43,600</td>
#       <td id="T_84eee_row1_col3" class="data row1 col3" >0.311927</td>
#       <td id="T_84eee_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_84eee_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_84eee_row1_col6" class="data row1 col6" >$13,600</td>
#       <td id="T_84eee_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row2_col0" class="data row2 col0" >$9,000</td>
#       <td id="T_84eee_row2_col1" class="data row2 col1" >6.96%</td>
#       <td id="T_84eee_row2_col2" class="data row2 col2" >$46,100</td>
#       <td id="T_84eee_row2_col3" class="data row2 col3" >0.349241</td>
#       <td id="T_84eee_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_84eee_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_84eee_row2_col6" class="data row2 col6" >$16,100</td>
#       <td id="T_84eee_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row3_col0" class="data row3 col0" >$10,700</td>
#       <td id="T_84eee_row3_col1" class="data row3 col1" >7.66%</td>
#       <td id="T_84eee_row3_col2" class="data row3 col2" >$52,700</td>
#       <td id="T_84eee_row3_col3" class="data row3 col3" >0.430740</td>
#       <td id="T_84eee_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_84eee_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_84eee_row3_col6" class="data row3 col6" >$22,700</td>
#       <td id="T_84eee_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row4_col0" class="data row4 col0" >$10,800</td>
#       <td id="T_84eee_row4_col1" class="data row4 col1" >7.70%</td>
#       <td id="T_84eee_row4_col2" class="data row4 col2" >$53,000</td>
#       <td id="T_84eee_row4_col3" class="data row4 col3" >0.433962</td>
#       <td id="T_84eee_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_84eee_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_84eee_row4_col6" class="data row4 col6" >$23,000</td>
#       <td id="T_84eee_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row5_col0" class="data row5 col0" >$10,100</td>
#       <td id="T_84eee_row5_col1" class="data row5 col1" >7.44%</td>
#       <td id="T_84eee_row5_col2" class="data row5 col2" >$50,600</td>
#       <td id="T_84eee_row5_col3" class="data row5 col3" >0.407115</td>
#       <td id="T_84eee_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_84eee_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_84eee_row5_col6" class="data row5 col6" >$20,600</td>
#       <td id="T_84eee_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row6_col0" class="data row6 col0" >$10,300</td>
#       <td id="T_84eee_row6_col1" class="data row6 col1" >7.49%</td>
#       <td id="T_84eee_row6_col2" class="data row6 col2" >$51,100</td>
#       <td id="T_84eee_row6_col3" class="data row6 col3" >0.412916</td>
#       <td id="T_84eee_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_84eee_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_84eee_row6_col6" class="data row6 col6" >$21,100</td>
#       <td id="T_84eee_row6_col7" class="data row6 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row7_col0" class="data row7 col0" >$8,800</td>
#       <td id="T_84eee_row7_col1" class="data row7 col1" >6.86%</td>
#       <td id="T_84eee_row7_col2" class="data row7 col2" >$45,100</td>
#       <td id="T_84eee_row7_col3" class="data row7 col3" >0.334812</td>
#       <td id="T_84eee_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_84eee_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_84eee_row7_col6" class="data row7 col6" >$15,100</td>
#       <td id="T_84eee_row7_col7" class="data row7 col7" >0</td>
#     </tr>
#     <tr>
#       <td id="T_84eee_row8_col0" class="data row8 col0" >$9,300</td>
#       <td id="T_84eee_row8_col1" class="data row8 col1" >7.10%</td>
#       <td id="T_84eee_row8_col2" class="data row8 col2" >$47,400</td>
#       <td id="T_84eee_row8_col3" class="data row8 col3" >0.367089</td>
#       <td id="T_84eee_row8_col4" class="data row8 col4" >3</td>
#       <td id="T_84eee_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_84eee_row8_col6" class="data row8 col6" >$17,400</td>
#       <td id="T_84eee_row8_col7" class="data row8 col7" >0</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## **1.2: Create the labels set (`y`)  from the “loan_status” column, and then create the features (`X`) DataFrame from the remaining columns.**

# %% [markdown]
# ### **Separate the y variable, the labels**

# %%
ySeries \
    = lendingDataFrame \
        ['loan_status']

log_function \
    .DebugReturnObjectWriteObject \
        (ySeries)

# %% [markdown]
# ### **Separate the X variable, the features**

# %%
xDataFrame \
    = lendingDataFrame \
        .drop \
            (columns = 'loan_status',
             axis = 1)

log_function \
    .DebugReturnObjectWriteObject \
        (xDataFrame)

# %% [markdown]
# ### **Review the Y Variable Series**

# %%
captionString \
    = 'Table 1.3.1: Y Variable Series'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (ySeries.to_frame().head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_cc16d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cc16d_row0_col0, #T_cc16d_row1_col0, #T_cc16d_row2_col0, #T_cc16d_row3_col0, #T_cc16d_row4_col0, #T_cc16d_row5_col0, #T_cc16d_row6_col0, #T_cc16d_row7_col0, #T_cc16d_row8_col0, #T_cc16d_row9_col0, #T_cc16d_row10_col0, #T_cc16d_row11_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_cc16d">
#   <caption>Table 1.3.1: Y Variable Series</caption>
#   <thead>
#     <tr>
#       <th id="T_cc16d_level0_col0" class="col_heading level0 col0" >loan_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cc16d_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <td id="T_cc16d_row11_col0" class="data row11 col0" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Review the X Variable DataFrame**

# %%
captionString \
    = 'Table 1.3.2: X Variable DataFrame'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (xDataFrame.head(12),
             captionString) \
        .format({'loan_size': '${:,.0f}',
                 'interest_rate': '{:.2f}%',
                 'borrower_income': '${:,.0f}',
                 'total_debt': '${:,.0f}'})

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_295c1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_295c1_row0_col0, #T_295c1_row0_col1, #T_295c1_row0_col2, #T_295c1_row0_col3, #T_295c1_row0_col4, #T_295c1_row0_col5, #T_295c1_row0_col6, #T_295c1_row1_col0, #T_295c1_row1_col1, #T_295c1_row1_col2, #T_295c1_row1_col3, #T_295c1_row1_col4, #T_295c1_row1_col5, #T_295c1_row1_col6, #T_295c1_row2_col0, #T_295c1_row2_col1, #T_295c1_row2_col2, #T_295c1_row2_col3, #T_295c1_row2_col4, #T_295c1_row2_col5, #T_295c1_row2_col6, #T_295c1_row3_col0, #T_295c1_row3_col1, #T_295c1_row3_col2, #T_295c1_row3_col3, #T_295c1_row3_col4, #T_295c1_row3_col5, #T_295c1_row3_col6, #T_295c1_row4_col0, #T_295c1_row4_col1, #T_295c1_row4_col2, #T_295c1_row4_col3, #T_295c1_row4_col4, #T_295c1_row4_col5, #T_295c1_row4_col6, #T_295c1_row5_col0, #T_295c1_row5_col1, #T_295c1_row5_col2, #T_295c1_row5_col3, #T_295c1_row5_col4, #T_295c1_row5_col5, #T_295c1_row5_col6, #T_295c1_row6_col0, #T_295c1_row6_col1, #T_295c1_row6_col2, #T_295c1_row6_col3, #T_295c1_row6_col4, #T_295c1_row6_col5, #T_295c1_row6_col6, #T_295c1_row7_col0, #T_295c1_row7_col1, #T_295c1_row7_col2, #T_295c1_row7_col3, #T_295c1_row7_col4, #T_295c1_row7_col5, #T_295c1_row7_col6, #T_295c1_row8_col0, #T_295c1_row8_col1, #T_295c1_row8_col2, #T_295c1_row8_col3, #T_295c1_row8_col4, #T_295c1_row8_col5, #T_295c1_row8_col6, #T_295c1_row9_col0, #T_295c1_row9_col1, #T_295c1_row9_col2, #T_295c1_row9_col3, #T_295c1_row9_col4, #T_295c1_row9_col5, #T_295c1_row9_col6, #T_295c1_row10_col0, #T_295c1_row10_col1, #T_295c1_row10_col2, #T_295c1_row10_col3, #T_295c1_row10_col4, #T_295c1_row10_col5, #T_295c1_row10_col6, #T_295c1_row11_col0, #T_295c1_row11_col1, #T_295c1_row11_col2, #T_295c1_row11_col3, #T_295c1_row11_col4, #T_295c1_row11_col5, #T_295c1_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_295c1">
#   <caption>Table 1.3.2: X Variable DataFrame</caption>
#   <thead>
#     <tr>
#       <th id="T_295c1_level0_col0" class="col_heading level0 col0" >loan_size</th>
#       <th id="T_295c1_level0_col1" class="col_heading level0 col1" >interest_rate</th>
#       <th id="T_295c1_level0_col2" class="col_heading level0 col2" >borrower_income</th>
#       <th id="T_295c1_level0_col3" class="col_heading level0 col3" >debt_to_income</th>
#       <th id="T_295c1_level0_col4" class="col_heading level0 col4" >num_of_accounts</th>
#       <th id="T_295c1_level0_col5" class="col_heading level0 col5" >derogatory_marks</th>
#       <th id="T_295c1_level0_col6" class="col_heading level0 col6" >total_debt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_295c1_row0_col0" class="data row0 col0" >$10,700</td>
#       <td id="T_295c1_row0_col1" class="data row0 col1" >7.67%</td>
#       <td id="T_295c1_row0_col2" class="data row0 col2" >$52,800</td>
#       <td id="T_295c1_row0_col3" class="data row0 col3" >0.431818</td>
#       <td id="T_295c1_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_295c1_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_295c1_row0_col6" class="data row0 col6" >$22,800</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row1_col0" class="data row1 col0" >$8,400</td>
#       <td id="T_295c1_row1_col1" class="data row1 col1" >6.69%</td>
#       <td id="T_295c1_row1_col2" class="data row1 col2" >$43,600</td>
#       <td id="T_295c1_row1_col3" class="data row1 col3" >0.311927</td>
#       <td id="T_295c1_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_295c1_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_295c1_row1_col6" class="data row1 col6" >$13,600</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row2_col0" class="data row2 col0" >$9,000</td>
#       <td id="T_295c1_row2_col1" class="data row2 col1" >6.96%</td>
#       <td id="T_295c1_row2_col2" class="data row2 col2" >$46,100</td>
#       <td id="T_295c1_row2_col3" class="data row2 col3" >0.349241</td>
#       <td id="T_295c1_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_295c1_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_295c1_row2_col6" class="data row2 col6" >$16,100</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row3_col0" class="data row3 col0" >$10,700</td>
#       <td id="T_295c1_row3_col1" class="data row3 col1" >7.66%</td>
#       <td id="T_295c1_row3_col2" class="data row3 col2" >$52,700</td>
#       <td id="T_295c1_row3_col3" class="data row3 col3" >0.430740</td>
#       <td id="T_295c1_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_295c1_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_295c1_row3_col6" class="data row3 col6" >$22,700</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row4_col0" class="data row4 col0" >$10,800</td>
#       <td id="T_295c1_row4_col1" class="data row4 col1" >7.70%</td>
#       <td id="T_295c1_row4_col2" class="data row4 col2" >$53,000</td>
#       <td id="T_295c1_row4_col3" class="data row4 col3" >0.433962</td>
#       <td id="T_295c1_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_295c1_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_295c1_row4_col6" class="data row4 col6" >$23,000</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row5_col0" class="data row5 col0" >$10,100</td>
#       <td id="T_295c1_row5_col1" class="data row5 col1" >7.44%</td>
#       <td id="T_295c1_row5_col2" class="data row5 col2" >$50,600</td>
#       <td id="T_295c1_row5_col3" class="data row5 col3" >0.407115</td>
#       <td id="T_295c1_row5_col4" class="data row5 col4" >4</td>
#       <td id="T_295c1_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_295c1_row5_col6" class="data row5 col6" >$20,600</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row6_col0" class="data row6 col0" >$10,300</td>
#       <td id="T_295c1_row6_col1" class="data row6 col1" >7.49%</td>
#       <td id="T_295c1_row6_col2" class="data row6 col2" >$51,100</td>
#       <td id="T_295c1_row6_col3" class="data row6 col3" >0.412916</td>
#       <td id="T_295c1_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_295c1_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_295c1_row6_col6" class="data row6 col6" >$21,100</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row7_col0" class="data row7 col0" >$8,800</td>
#       <td id="T_295c1_row7_col1" class="data row7 col1" >6.86%</td>
#       <td id="T_295c1_row7_col2" class="data row7 col2" >$45,100</td>
#       <td id="T_295c1_row7_col3" class="data row7 col3" >0.334812</td>
#       <td id="T_295c1_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_295c1_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_295c1_row7_col6" class="data row7 col6" >$15,100</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row8_col0" class="data row8 col0" >$9,300</td>
#       <td id="T_295c1_row8_col1" class="data row8 col1" >7.10%</td>
#       <td id="T_295c1_row8_col2" class="data row8 col2" >$47,400</td>
#       <td id="T_295c1_row8_col3" class="data row8 col3" >0.367089</td>
#       <td id="T_295c1_row8_col4" class="data row8 col4" >3</td>
#       <td id="T_295c1_row8_col5" class="data row8 col5" >0</td>
#       <td id="T_295c1_row8_col6" class="data row8 col6" >$17,400</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row9_col0" class="data row9 col0" >$9,700</td>
#       <td id="T_295c1_row9_col1" class="data row9 col1" >7.25%</td>
#       <td id="T_295c1_row9_col2" class="data row9 col2" >$48,800</td>
#       <td id="T_295c1_row9_col3" class="data row9 col3" >0.385246</td>
#       <td id="T_295c1_row9_col4" class="data row9 col4" >4</td>
#       <td id="T_295c1_row9_col5" class="data row9 col5" >0</td>
#       <td id="T_295c1_row9_col6" class="data row9 col6" >$18,800</td>
#     </tr>
#     <tr>
#       <td id="T_295c1_row10_col0" class="data row10 col0" >$9,300</td>
#       <td id="T_295c1_row10_col1" class="data row10 col1" >7.08%</td>
#       <td id="T_295c1_row10_col2" class="data row10 col2" >$47,300</td>
#       <td id="T_295c1_row10_col3" class="data row10 col3" >0.365751</td>
#       <td id="T_295c1_row10_col4" class="data row10 col4" >3</td>
#       <td id="T_295c1_row10_col5" class="data row10 col5

# %% [markdown]
# ## **1.3: Check the balance of the labels variable (`y`) by using the `value_counts` function.**

# %%
ySeries.value_counts()
# Out:
# loan_status
# 0    75036
# 1     2500
# Name: count, dtype: int64

# %% [markdown]
# ## **1.4: Split the data into training and testing datasets by using `train_test_split`.**

# %%
xTrainDataFrame, \
xTestDataFrame, \
yTrainSeries, \
yTestSeries \
    = train_test_split \
        (xDataFrame, 
         ySeries, 
         random_state = 1)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (xTrainDataFrame)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (xTestDataFrame)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (yTrainSeries)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (yTestSeries)

# %% [markdown]
# # <br> **Section 2: Create a Logistic Regression Model with the Original Data**

# %% [markdown]
# ## **2.1: Fit a logistic regression model by using the training data.**

# %%
# This line of code assigns a random_state parameter of 1 to the model
# and fits the model using training data.
modelLogisticRegression \
    = LogisticRegression \
        (random_state = 1) \
            .fit \
                (xTrainDataFrame, 
                 yTrainSeries)

log_function \
    .DebugReturnObjectWriteObject \
        (modelLogisticRegression)

# %% [markdown]
# ## **2.2: Save the predictions on the testing data labels by using the testing feature data and the fitted model.**

# %%
predictionsNumpyArray \
    = modelLogisticRegression \
        .predict \
            (xTestDataFrame)

log_function \
    .DebugReturnObjectWriteObject \
        (predictionsNumpyArray)

# %%
predictionDictionary \
    = {'Prediction': predictionsNumpyArray, 
       'Actual': yTestSeries}

predictionDataFrame \
    = pd.DataFrame \
        (predictionDictionary)

log_function \
    .DebugReturnObjectWriteObject \
        (predictionDataFrame)

# %%
captionString \
    = 'Table 2.2.1: Testing Data Label Predictions (Original)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (predictionDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_d383c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d383c_row0_col0, #T_d383c_row0_col1, #T_d383c_row1_col0, #T_d383c_row1_col1, #T_d383c_row2_col0, #T_d383c_row2_col1, #T_d383c_row3_col0, #T_d383c_row3_col1, #T_d383c_row4_col0, #T_d383c_row4_col1, #T_d383c_row5_col0, #T_d383c_row5_col1, #T_d383c_row6_col0, #T_d383c_row6_col1, #T_d383c_row7_col0, #T_d383c_row7_col1, #T_d383c_row8_col0, #T_d383c_row8_col1, #T_d383c_row9_col0, #T_d383c_row9_col1, #T_d383c_row10_col0, #T_d383c_row10_col1, #T_d383c_row11_col0, #T_d383c_row11_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_d383c">
#   <caption>Table 2.2.1: Testing Data Label Predictions (Original)</caption>
#   <thead>
#     <tr>
#       <th id="T_d383c_level0_col0" class="col_heading level0 col0" >Prediction</th>
#       <th id="T_d383c_level0_col1" class="col_heading level0 col1" >Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d383c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d383c_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d383c_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d383c_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_d383c_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_d383c_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_d383c_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d383c_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_d383c_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_d383c_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_d383c_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_d383c_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d383c_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_d383c_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **2.3: Evaluate the model’s performance**

# %%
accuracyScoreOriginalFloat, \
confusionMatrixOriginalDataFrame, \
classificationReportOriginalString \
    = local_function \
        .ModelPerformanceEvaluatorFunction \
            (yTestSeries,
             predictionsNumpyArray)
# Out:
# LOGISTIC REGRESSION MODEL (Original)
#
# 1) Accuracy Score: 95.2%
#
# 2) Confusion Matrix:
#
#                   Predicted Healthy  Predicted High-Risk
# Actual Healthy                18663                  102
# Actual High-Risk                 56                  563
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#      healthy       1.00      0.99      1.00     18765
#    high risk       0.85      0.91      0.88       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.95      0.94     19384
# weighted avg       0.99      0.99      0.99     19384

# %% [markdown]
# ## **Question:**
# ### How well does the logistic regression model predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# ## **Answer:**
# ### This logistic regression model does an excellent job predicting healthy loans with a small number of false positives and negatives leading to a precision score of 100%, a recall score of 99%, and an f1-score of 100%.  Nevertheless, this model less accurately predicts high-risk loans with a precision of 85%, a recall of 91%, and an f1-score of 88%. The balanced accuracy, 99%, is higher than the actual accuracy, 95%, because of the significant discrepancy in label value counts, 75,036 vs. 2,500. The model's potential for an increase in accuracy and the comparatively inadequate performance in predicting high-risk loans vs health loans are concerning. Thus, the model warrants further optimization either by closing the value count gap with additional data or random oversampling.

# %% [markdown]
# # <br> **Section 3: Predict a Logistic Regression Model with Resampled Training Data**

# %% [markdown]
# ## **3.1: Use the `RandomOverSampler` module from the imbalanced-learn library to resample the data. Be sure to confirm that the labels have an equal number of data points.**

# %% [markdown]
# ### **Instantiate the Random Oversampler Model**

# %%
xResampledDataFrame, \
yResampledSeries \
    = RandomOverSampler \
        (random_state = 1) \
            .fit_resample \
                (xTrainDataFrame, 
                 yTrainSeries)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (xResampledDataFrame)

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (yResampledSeries)

# %% [markdown]
# ### **Count the distinct values of the resampled labels data**

# %%
yResampledSeries.value_counts()
# Out:
# loan_status
# 0    56271
# 1    56271
# Name: count, dtype: int64

# %% [markdown]
# ## **3.2: Use the `LogisticRegression` classifier and the resampled data to fit the model and make predictions.**

# %% [markdown]
# ### **Fit a logistic regression model by using the training data.**

# %%
# This line of code assigns a random_state parameter of 1 to the model
# and fits the model using training data.
modelResampledLogisticRegression \
    = LogisticRegression \
        (random_state = 1) \
            .fit \
                (xResampledDataFrame, 
                 yResampledSeries)

log_function \
    .DebugReturnObjectWriteObject \
        (modelResampledLogisticRegression)

# %% [markdown]
# ### **Save the predictions on the testing data labels by using the testing feature data and the fitted model.**

# %%
predictionsResampledNumpyArray \
    = modelResampledLogisticRegression \
        .predict \
            (xTestDataFrame)

log_function \
    .DebugReturnObjectWriteObject \
        (predictionsResampledNumpyArray)

# %%
predictionResampledDictionary \
    = {'Prediction': predictionsResampledNumpyArray, 
       'Actual': yTestSeries}

predictionResampledDataFrame \
    = pd.DataFrame \
        (predictionResampledDictionary) \
            .reset_index \
                (drop = True)

log_function \
    .DebugReturnObjectWriteObject \
        (predictionResampledDataFrame)

# %%
captionString \
    = 'Table 2.2.1: Testing Data Label Predictions (Resampled)'

currentStylerObject \
    = function \
        .ReturnStylerObjectStandardFormat \
            (predictionResampledDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_aa76e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_aa76e_row0_col0, #T_aa76e_row0_col1, #T_aa76e_row1_col0, #T_aa76e_row1_col1, #T_aa76e_row2_col0, #T_aa76e_row2_col1, #T_aa76e_row3_col0, #T_aa76e_row3_col1, #T_aa76e_row4_col0, #T_aa76e_row4_col1, #T_aa76e_row5_col0, #T_aa76e_row5_col1, #T_aa76e_row6_col0, #T_aa76e_row6_col1, #T_aa76e_row7_col0, #T_aa76e_row7_col1, #T_aa76e_row8_col0, #T_aa76e_row8_col1, #T_aa76e_row9_col0, #T_aa76e_row9_col1, #T_aa76e_row10_col0, #T_aa76e_row10_col1, #T_aa76e_row11_col0, #T_aa76e_row11_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_aa76e">
#   <caption>Table 2.2.1: Testing Data Label Predictions (Resampled)</caption>
#   <thead>
#     <tr>
#       <th id="T_aa76e_level0_col0" class="col_heading level0 col0" >Prediction</th>
#       <th id="T_aa76e_level0_col1" class="col_heading level0 col1" >Actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa76e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_aa76e_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_aa76e_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_aa76e_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_aa76e_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_aa76e_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_aa76e_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_aa76e_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_aa76e_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_aa76e_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_aa76e_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_aa76e_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_aa76e_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_aa76e_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.3: Evaluate the model’s performance with resampled data.**

# %%
accuracyScoreOriginalFloat, \
confusionMatrixOriginalDataFrame, \
classificationReportOriginalString \
    = local_function \
        .ModelPerformanceEvaluatorFunction \
            (yTestSeries,
             predictionsResampledNumpyArray,
             False)
# Out:
# LOGISTIC REGRESSION MODEL (Random Oversampling)
#
# 1) Accuracy Score: 99.4%
#
# 2) Confusion Matrix:
#
#                   Predicted Healthy  Predicted High-Risk
# Actual Healthy                18649                  116
# Actual High-Risk                  4                  615
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#      healthy       1.00      0.99      1.00     18765
#    high risk       0.84      0.99      0.91       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.99      0.95     19384
# weighted avg       0.99      0.99      0.99     19384

# %% [markdown]
# ## **Question:**
# ### How well does the logistic regression model, fit with oversampled data, predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# ## **Answer:**
#
# ### In terms of accuracy, this logistic regression model with random oversampling matches the first model for predicting healthy loans and outperforms it for high-risk loans. For instance, the number of accepted healthy loans falls (18,663 to 18,649); the number of rejected high-risk loans expands (563 to 615); the number of false positives increases slightly (102 to 116); and the number of false negatives significantly drops (56 to 4). Moreover, using random oversampling to generate additional synthetic samples for the minority class eliminates the label value count discrepancy leading to, among other things, the balanced accuracy score matching the overall accuracy score, 99%. For healthy loans, both models have 100% precision, 99% recall, and 100% f1-scores; for high-risk loans, although the precision, 85%, declines by 1% to 84%, the recall, 92%, increases by 8% to 99%, and the f1-score, 88%, increases by 3% to 91%. Consequently, using random oversampling with the logistic regression model maintains its identification of healthy loans while improving its identification of high-risk loans.

# %%
#log_subroutine \
#    .EndProgramExecution()
